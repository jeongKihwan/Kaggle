# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus']= False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_csv('data/뇌졸중예측.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.columns = ['고유ID','성별','나이','고혈압','심장질환','검사','직업유형','거주유형','평균포도당수치','체질량지수','흡연상태','뇌졸중']

# %%
df.head()
# Out:
#     고유ID      성별    나이  고혈압  심장질환   검사           직업유형   거주유형  평균포도당수치  체질량지수  \
# 0   9046    Male  67.0    0     1  Yes        Private  Urban   228.69   36.6
# 1  51676  Female  61.0    0     0  Yes  Self-employed  Rural   202.21    NaN
# 2  31112    Male  80.0    0     1  Yes        Private  Rural   105.92   32.5
# 3  60182  Female  49.0    0     0  Yes        Private  Urban   171.23   34.4
# 4   1665  Female  79.0    1     0  Yes  Self-employed  Rural   174.12   24.0
#
#               흡연상태  뇌졸중
# 0  formerly smoked    1
# 1     never smoked    1
# 2     never smoked    1
# 3           smokes    1
# 4     never smoked    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   고유ID     5110 non-null   int64
#  1   성별       5110 non-null   object
#  2   나이       5110 non-null   float64
#  3   고혈압      5110 non-null   int64
#  4   심장질환     5110 non-null   int64
#  5   검사       5110 non-null   object
#  6   직업유형     5110 non-null   object
#  7   거주유형     5110 non-null   object
#  8   평균포도당수치  5110 non-null   float64
#  9   체질량지수    4909 non-null   float64
#  10  흡연상태     5110 non-null   object
#  11  뇌졸중      5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.isnull().sum()
# Out:
# 고유ID         0
# 성별           0
# 나이           0
# 고혈압          0
# 심장질환         0
# 검사           0
# 직업유형         0
# 거주유형         0
# 평균포도당수치      0
# 체질량지수      201
# 흡연상태         0
# 뇌졸중          0
# dtype: int64

# %%
df.체질량지수.replace(to_replace=np.nan, value=df.체질량지수.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# 고유ID       0
# 성별         0
# 나이         0
# 고혈압        0
# 심장질환       0
# 검사         0
# 직업유형       0
# 거주유형       0
# 평균포도당수치    0
# 체질량지수      0
# 흡연상태       0
# 뇌졸중        0
# dtype: int64

# %%
df.describe()
# Out:
#                고유ID           나이          고혈압         심장질환      평균포도당수치  \
# count   5110.000000  5110.000000  5110.000000  5110.000000  5110.000000
# mean   36517.829354    43.226614     0.097456     0.054012   106.147677
# std    21161.721625    22.612647     0.296607     0.226063    45.283560
# min       67.000000     0.080000     0.000000     0.000000    55.120000
# 25%    17741.250000    25.000000     0.000000     0.000000    77.245000
# 50%    36932.000000    45.000000     0.000000     0.000000    91.885000
# 75%    54682.000000    61.000000     0.000000     0.000000   114.090000
# max    72940.000000    82.000000     1.000000     1.000000   271.740000
#
#              체질량지수          뇌졸중
# count  5110.000000  5110.000000
# mean     28.893237     0.048728
# std       7.698018     0.215320
# min      10.300000     0.000000
# 25%      23.800000     0.000000
# 50%      28.400000     0.000000
# 75%      32.800000     0.000000
# max      97.600000     1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df.성별)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.고혈압)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.심장질환)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.검사)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.직업유형)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.거주유형)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.흡연상태)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.뇌졸중)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(df.평균포도당수치,kde=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.체질량지수, kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='체질량지수', ylabel='Density'>

# %%
plt.figure(figsize=(12,10))

sns.distplot(df[df.뇌졸중 == 0]['체질량지수'],color='blue')
sns.distplot(df[df.뇌졸중 == 1]['체질량지수'],color='red')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='체질량지수', ylabel='Density'>

# %%
plt.figure(figsize=(12,10))

sns.distplot(df[df.뇌졸중 == 0]['평균포도당수치'],color='blue')
sns.distplot(df[df.뇌졸중 == 1]['평균포도당수치'],color='red')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='평균포도당수치', ylabel='Density'>

# %%
plt.figure(figsize=(12,10))

sns.distplot(df[df.뇌졸중 == 0]['나이'],color='blue')
sns.distplot(df[df.뇌졸중 == 1]['나이'],color='red')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='나이', ylabel='Density'>

# %%
sns.scatterplot(x=df.나이,y=df.체질량지수,hue=df.성별)
# Out:
# <AxesSubplot:xlabel='나이', ylabel='체질량지수'>

# %%
sns.pairplot(df)
